# %% [markdown]
# ## AT Content Calculator
#
# AT content is the percentage of Adenine (A) and Thymine (T) nucleotides
# in a DNA sequence. It is often used along with GC content to understand
# DNA stability and composition.

# %%
def at_content(sequence):
    sequence = sequence.upper()
    at_count = sequence.count("A") + sequence.count("T")
    return round((at_count / len(sequence)) * 100, 2)

dna_seq = "AGCTATAGCGCGATATGC"

print("DNA Sequence:", dna_seq)
print("AT Content:", at_content(dna_seq), "%")
# Out:
# DNA Sequence: AGCTATAGCGCGATATGC
# AT Content: 50.0 %

# %% [markdown]
# ### Optional: Compare AT Content with GC Content
# In DNA, AT content + GC content = 100%.

# %%
def gc_content(sequence):
    sequence = sequence.upper()
    gc_count = sequence.count("G") + sequence.count("C")
    return round((gc_count / len(sequence)) * 100, 2)

print("GC Content:", gc_content(dna_seq), "%")
# Out:
# GC Content: 50.0 %

# %%
print("AT + GC =", at_content(dna_seq) + gc_content(dna_seq), "%")
# Out:
# AT + GC = 100.0 %
